# %% [markdown]
# # Tokenizer V1

# %% [markdown]
# ## Imports

# %% [markdown]
# ## Training our own tokenizer

# %% [markdown]
# ### Step-1: Starting with a Training Corpus
#
# Here we have made a dummy corpus of 4 documents represented in a List

# %%
corpus = ["The model’s performance improved slightly after fine-tuning on domain-specific data.",
          "A lightweight transformer can often outperform larger models when properly optimized.",
          "Experimental results show that scaling depth contributes more to coherence than width.",
          "Future work could explore hybrid architectures combining attention with retrieval mechanisms."
          ]
print("Training Corpus: ")
for doc in corpus:
  print(doc)
# Out:
# Training Corpus:
# The model’s performance improved slightly after fine-tuning on domain-specific data.
# A lightweight transformer can often outperform larger models when properly optimized.
# Experimental results show that scaling depth contributes more to coherence than width.
# Future work could explore hybrid architectures combining attention with retrieval mechanisms.

# %%
unique_characters = set()
for doc in corpus:
  for char in doc:
    unique_characters.add(char)

vocabulary = list(unique_characters)
vocabulary.sort()

vocabulary
# Out:
# [' ',
#  '-',
#  '.',
#  'A',
#  'E',
#  'F',
#  'T',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'x',
#  'y',
#  'z',
#  '’']

# %%
end_of_word_token = "<|eos|>"
start_of_word_token = "<|sos|>"

vocabulary.append(end_of_word_token)
vocabulary.append(start_of_word_token)

vocabulary
# Out:
# [' ',
#  '-',
#  '.',
#  'A',
#  'E',
#  'F',
#  'T',
#  'a',
#  'b',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'x',
#  'y',
#  'z',
#  '’',
#  '<|eos|>',
#  '<|sos|>']

# %%
len(vocabulary)
# Out:
# 34

# %%
word_splits = {}
for doc in corpus:
  for word in doc.split(' '):
    if word:
      char_list = [start_of_word_token] + list(word) + [end_of_word_token]
      word_tuple = tuple(char_list)

      if word_tuple not in word_splits:
        word_splits[word_tuple] = 0
      word_splits[word_tuple] += 1

word_splits
# Out:
# {('<|sos|>', 'T', 'h', 'e', '<|eos|>'): 1,
#  ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1,
#  ('<|sos|>',
#   'p',
#   'e',
#   'r',
#   'f',
#   'o',
#   'r',
#   'm',
#   'a',
#   'n',
#   'c',
#   'e',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1,
#  ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1,
#  ('<|sos|>', 'a', 'f', 't', 'e', 'r', '<|eos|>'): 1,
#  ('<|sos|>',
#   'f',
#   'i',
#   'n',
#   'e',
#   '-',
#   't',
#   'u',
#   'n',
#   'i',
#   'n',
#   'g',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'o', 'n', '<|eos|>'): 1,
#  ('<|sos|>',
#   'd',
#   'o',
#   'm',
#   'a',
#   'i',
#   'n',
#   '-',
#   's',
#   'p',
#   'e',
#   'c',
#   'i',
#   'f',
#   'i',
#   'c',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1,
#  ('<|sos|>', 'A', '<|eos|>'): 1,
#  ('<|sos|>',
#   'l',
#   'i',
#   'g',
#   'h',
#   't',
#   'w',
#   'e',
#   'i',
#   'g',
#   'h',
#   't',
#   '<|eos|>'): 1,
#  ('<|sos|>',
#   't',
#   'r',
#   'a',
#   'n',
#   's',
#   'f',
#   'o',
#   'r',
#   'm',
#   'e',
#   'r',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1,
#  ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1,
#  ('<|sos|>', 'o', 'u', 't', 'p', 'e', 'r', 'f', 'o', 'r', 'm', '<|eos|>'): 1,
#  ('<|sos|>', 'l', 'a', 'r', 'g', 'e', 'r', '<|eos|>'): 1,
#  ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1,
#  ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1,
#  ('<|sos|>', 'p', 'r', 'o', 'p', 'e', 'r', 'l', 'y', '<|eos|>'): 1,
#  ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1,
#  ('<|sos|>',
#   'E',
#   'x',
#   'p',
#   'e',
#   'r',
#   'i',
#   'm',
#   'e',
#   'n',
#   't',
#   'a',
#   'l',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1,
#  ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1,
#  ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1,
#  ('<|sos|>', 's', 'c', 'a', 'l', 'i', 'n', 'g', '<|eos|>'): 1,
#  ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1,
#  ('<|sos|>',
#   'c',
#   'o',
#   'n',
#   't',
#   'r',
#   'i',
#   'b',
#   'u',
#   't',
#   'e',
#   's',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'm', 'o', 'r', 'e', '<|eos|>'): 1,
#  ('<|sos|>', 't', 'o', '<|eos|>'): 1,
#  ('<|sos|>', 'c', 'o', 'h', 'e', 'r', 'e', 'n', 'c', 'e', '<|eos|>'): 1,
#  ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1,
#  ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1,
#  ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e', '<|eos|>'): 1,
#  ('<|sos|>', 'w', 'o', 'r', 'k', '<|eos|>'): 1,
#  ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1,
#  ('<|sos|>', 'e', 'x', 'p', 'l', 'o', 'r', 'e', '<|eos|>'): 1,
#  ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1,
#  ('<|sos|>',
#   'a',
#   'r',
#   'c',
#   'h',
#   'i',
#   't',
#   'e',
#   'c',
#   't',
#   'u',
#   'r',
#   'e',
#   's',
#   '<|eos|>'): 1,
#  ('<|sos|>', 'c', 'o', 'm', 'b', 'i', 'n', 'i', 'n', 'g', '<|eos|>'): 1,
#  ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1,
#  ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1,
#  ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1,
#  ('<|sos|>',
#   'm',
#   'e',
#   'c',
#   'h',
#   'a',
#   'n',
#   'i',
#   's',
#   'm',
#   's',
#   '.',
#   '<|eos|>'): 1}

# %%
import collections
def get_pairs(splits):
  pairs = collections.defaultdict(int)
  for word, freq in splits.items():
    symbols = list(word)
    for i in range(len(symbols)-1):
      pair = (symbols[i], symbols[i+1])
      pairs[pair] += freq
  return pairs

get_pairs(word_splits)
# Out:
# defaultdict(int,
#             {('<|sos|>', 'T'): 1,
#              ('T', 'h'): 1,
#              ('h', 'e'): 3,
#              ('e', '<|eos|>'): 6,
#              ('<|sos|>', 'm'): 4,
#              ('m', 'o'): 3,
#              ('o', 'd'): 2,
#              ('d', 'e'): 3,
#              ('e', 'l'): 2,
#              ('l', '’'): 1,
#              ('’', 's'): 1,
#              ('s', '<|eos|>'): 5,
#              ('<|sos|>', 'p'): 2,
#              ('p', 'e'): 5,
#              ('e', 'r'): 8,
#              ('r', 'f'): 2,
#              ('f', 'o'): 3,
#              ('o', 'r'): 6,
#              ('r', 'm'): 3,
#              ('m', 'a'): 2,
#              ('a', 'n'): 5,
#              ('n', 'c'): 2,
#              ('c', 'e'): 2,
#              ('<|sos|>', 'i'): 1,
#              ('i', 'm'): 3,
#              ('m', 'p'): 1,
#              ('p', 'r'): 2,
#              ('r', 'o'): 2,
#              ('o', 'v'): 1,
#              ('v', 'e'): 1,
#              ('e', 'd'): 2,
#              ('d', '<|eos|>'): 3,
#              ('<|sos|>', 's'): 3,
#              ('s', 'l'): 1,
#              ('l', 'i'): 3,
#              ('i', 'g'): 3,
#              ('g', 'h'): 3,
#              ('h', 't'): 3,
#              ('t', 'l'): 1,
#              ('l', 'y'): 2,
#              ('y', '<|eos|>'): 2,
#              ('<|sos|>', 'a'): 3,
#              ('a', 'f'): 1,
#              ('f', 't'): 2,
#              ('t', 'e'): 5,
#              ('r', '<|eos|>'): 3,
#              ('<|sos|>', 'f'): 1,
#              ('f', 'i'): 2,
#              ('i', 'n'): 6,
#              ('n', 'e'): 1,
#              ('e', '-'): 1,
#              ('-', 't'): 1,
#              ('t', 'u'): 3,
#              ('u', 'n'): 1,
#              ('n', 'i'): 3,
#              ('n', 'g'): 3,
#              ('g', '<|eos|>'): 3,
#              ('<|sos|>', 'o'): 4,
#              ('o', 'n'): 3,
#              ('n', '<|eos|>'): 6,
#              ('<|sos|>', 'd'): 3,
#              ('d', 'o'): 1,
#              ('o', 'm'): 2,
#              ('a', 'i'): 1,
#              ('n', '-'): 1,
#              ('-', 's'): 1,
#              ('s', 'p'): 1,
#              ('e', 'c'): 3,
#              ('c', 'i'): 1,
#              ('i', 'f'): 1,
#              ('i', 'c'): 1,
#              ('c', '<|eos|>'): 1,
#              ('d', 'a'): 1,
#              ('a', 't'): 3,
#              ('t', 'a'): 2,
#              ('a', '.'): 1,
#              ('.', '<|eos|>'): 4,
#              ('<|sos|>', 'A'): 1,
#              ('A', '<|eos|>'): 1,
#              ('<|sos|>', 'l'): 2,
#              ('t', 'w'): 1,
#              ('w', 'e'): 1,
#              ('e', 'i'): 1,
#              ('t', '<|eos|>'): 2,
#              ('<|sos|>', 't'): 4,
#              ('t', 'r'): 3,
#              ('r', 'a'): 1,
#              ('n', 's'): 1,
#              ('s', 'f'): 1,
#              ('m', 'e'): 3,
#              ('<|sos|>', 'c'): 5,
#              ('c', 'a'): 2,
#              ('o', 'f'): 1,
#              ('e', 'n'): 5,
#              ('o', 'u'): 2,
#              ('u', 't'): 3,
#              ('t', 'p'): 1,
#              ('m', '<|eos|>'): 1,
#              ('l', 'a'): 1,
#              ('a', 'r'): 2,
#              ('r', 'g'): 1,
#              ('g', 'e'): 1,
#              ('l', 's'): 1,
#              ('<|sos|>', 'w'): 4,
#              ('w', 'h'): 1,
#              ('o', 'p'): 2,
#              ('r', 'l'): 1,
#              ('p', 't'): 2,
#              ('t', 'i'): 2,
#              ('m', 'i'): 1,
#              ('i', 'z'): 1,
#              ('z', 'e'): 1,
#              ('d', '.'): 1,
#              ('<|sos|>', 'E'): 1,
#              ('E', 'x'): 1,
#              ('x', 'p'): 2,
#              ('r', 'i'): 4,
#              ('n', 't'): 3,
#              ('a', 'l'): 3,
#              ('l', '<|eos|>'): 2,
#              ('<|sos|>', 'r'): 2,
#              ('r', 'e'): 7,
#              ('e', 's'): 3,
#              ('s', 'u'): 1,
#              ('u', 'l'): 2,
#              ('l', 't'): 1,
#              ('t', 's'): 1,
#              ('s', 'h'): 1,
#              ('h', 'o'): 1,
#              ('o', 'w'): 1,
#              ('w', '<|eos|>'): 1,
#              ('t', 'h'): 5,
#              ('h', 'a'): 3,
#              ('s', 'c'): 1,
#              ('e', 'p'): 1,
#              ('h', '<|eos|>'): 2,
#              ('c', 'o'): 4,
#              ('i', 'b'): 1,
#              ('b', 'u'): 1,
#              ('t', 'o'): 1,
#              ('o', '<|eos|>'): 1,
#              ('o', 'h'): 1,
#              ('w', 'i'): 2,
#              ('i', 'd'): 2,
#              ('d', 't'): 1,
#              ('h', '.'): 1,
#              ('<|sos|>', 'F'): 1,
#              ('F', 'u'): 1,
#              ('u', 'r'): 2,
#              ('w', 'o'): 1,
#              ('r', 'k'): 1,
#              ('k', '<|eos|>'): 1,
#              ('l', 'd'): 1,
#              ('<|sos|>', 'e'): 1,
#              ('e', 'x'): 1,
#              ('p', 'l'): 1,
#              ('l', 'o'): 1,
#              ('<|sos|>', 'h'): 1,
#              ('h', 'y'): 1,
#              ('y', 'b'): 1,
#              ('b', 'r'): 1,
#              ('r', 'c'): 1,
#              ('c', 'h'): 2,
#              ('h', 'i'): 1,
#              ('i', 't'): 2,
#              ('c', 't'): 1,
#              ('m', 'b'): 1,
#              ('b', 'i'): 1,
#              ('t', 't'): 1,
#              ('i', 'o'): 1,
#              ('e', 't'): 1,
#              ('i', 'e'): 1,
#              ('e', 'v'): 1,
#              ('v', 'a'): 1,
#              ('i', 's'): 1,
#              ('s', 'm'): 1,
#              ('m', 's'): 1,
#              ('s', '.'): 1})

# %%
def merge_pair(pair, splits):
  new_splits = {}
  (first, second) = pair
  merged_token = first + second
  for word, freq in splits.items():
    symbols = list(word)
    new_symbols = list()
    i=0
    while i < len(symbols):
      if i < len(symbols)-1 and symbols[i] == first and symbols[i+1] == second:
        new_symbols.append(merged_token)
        i += 2
      else:
        new_symbols.append(symbols[i])
        i += 1
    new_splits[tuple(new_symbols)] = freq

  return new_splits

# %%
num_merges = 15

merges = {}

current_splits = word_splits.copy()

print("Starting BPE Merges\n")
print(f"Initial Splits: {current_splits}")
print("*"*30)

for i in range(num_merges):
  print(f"\nIteration {i+1}/{num_merges}")
  pairs = get_pairs(current_splits)
  if not pairs:
    print("No more pairs to merge")
    break

  sorted_pairs = sorted(pairs.items(), key=lambda x: x[1], reverse=True)
  print(f"\nTop 5 Pair Frequencies: {sorted_pairs[:5]}")

  best_pair = max(pairs, key=pairs.get)
  best_freq = pairs[best_pair]
  print(f"\nFound Best Pair: {best_pair}: best_freq: {best_freq}")

  current_splits = merge_pair(best_pair, current_splits)
  new_token = best_pair[0] + best_pair[1]
  print(f"\nMerging {best_pair} into {new_token}")
  print(f"\n Splits after merge: {current_splits}")

  vocabulary.append(new_token)
  merges[best_pair] = new_token
  print("*"*30)
# Out:
# Starting BPE Merges
#
# Initial Splits: {('<|sos|>', 'T', 'h', 'e', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'e', 'r', 'f', 'o', 'r', 'm', 'a', 'n', 'c', 'e', '<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'e', 'r', '<|eos|>'): 1, ('<|sos|>', 'f', 'i', 'n', 'e', '-', 't', 'u', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'i', 'n', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'o', 'r', 'm', 'e', 'r', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'e', 'r', 'f', 'o', 'r', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'e', 'r', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'e', 'r', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'e', 'r', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'e', 'r', 'e', 'n', 'c', 'e', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 'w', 'o', 'r', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'o', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'i', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 1/15
#
# Top 5 Pair Frequencies: [(('e', 'r'), 8), (('r', 'e'), 7), (('e', '<|eos|>'), 6), (('o', 'r'), 6), (('i', 'n'), 6)]
#
# Found Best Pair: ('e', 'r'): best_freq: 8
#
# Merging ('e', 'r') into er
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'o', 'r', 'm', 'a', 'n', 'c', 'e', '<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'i', 'n', 'e', '-', 't', 'u', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'i', 'n', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'o', 'r', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'o', 'r', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 'w', 'o', 'r', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'o', 'r', 'e', '<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'i', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 2/15
#
# Top 5 Pair Frequencies: [(('e', '<|eos|>'), 6), (('o', 'r'), 6), (('i', 'n'), 6), (('n', '<|eos|>'), 6), (('r', 'e'), 6)]
#
# Found Best Pair: ('e', '<|eos|>'): best_freq: 6
#
# Merging ('e', '<|eos|>') into e<|eos|>
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'o', 'r', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'i', 'n', 'e', '-', 't', 'u', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'i', 'n', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'o', 'r', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'o', 'r', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'r', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'o', 'r', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'o', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'i', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 3/15
#
# Top 5 Pair Frequencies: [(('o', 'r'), 6), (('i', 'n'), 6), (('n', '<|eos|>'), 6), (('s', '<|eos|>'), 5), (('a', 'n'), 5)]
#
# Found Best Pair: ('o', 'r'): best_freq: 6
#
# Merging ('o', 'r') into or
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'i', 'n', 'e', '-', 't', 'u', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'i', 'n', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'i', 'n', 'i', 'n', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 4/15
#
# Top 5 Pair Frequencies: [(('i', 'n'), 6), (('n', '<|eos|>'), 6), (('s', '<|eos|>'), 5), (('a', 'n'), 5), (('<|sos|>', 'c'), 5)]
#
# Found Best Pair: ('i', 'n'): best_freq: 6
#
# Merging ('i', 'n') into in
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n', '<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 5/15
#
# Top 5 Pair Frequencies: [(('n', '<|eos|>'), 6), (('s', '<|eos|>'), 5), (('a', 'n'), 5), (('<|sos|>', 'c'), 5), (('e', 'n'), 5)]
#
# Found Best Pair: ('n', '<|eos|>'): best_freq: 6
#
# Merging ('n', '<|eos|>') into n<|eos|>
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's', '<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's', '<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's', '<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 6/15
#
# Top 5 Pair Frequencies: [(('s', '<|eos|>'), 5), (('<|sos|>', 'c'), 5), (('t', 'h'), 5), (('<|sos|>', 'm'), 4), (('p', 'er'), 4)]
#
# Found Best Pair: ('s', '<|eos|>'): best_freq: 5
#
# Merging ('s', '<|eos|>') into s<|eos|>
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>', 'c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>', 'c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 7/15
#
# Top 5 Pair Frequencies: [(('<|sos|>', 'c'), 5), (('t', 'h'), 5), (('<|sos|>', 'm'), 4), (('p', 'er'), 4), (('<|sos|>', 'o'), 4)]
#
# Found Best Pair: ('<|sos|>', 'c'): best_freq: 5
#
# Merging ('<|sos|>', 'c') into <|sos|>c
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 't', 'h', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 't', 'h', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 't', 'h', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 't', 'h', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 8/15
#
# Top 5 Pair Frequencies: [(('t', 'h'), 5), (('<|sos|>', 'm'), 4), (('p', 'er'), 4), (('<|sos|>', 'o'), 4), (('.', '<|eos|>'), 4)]
#
# Found Best Pair: ('t', 'h'): best_freq: 5
#
# Merging ('t', 'h') into th
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>', 'm', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>', 'm', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'm', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 9/15
#
# Top 5 Pair Frequencies: [(('<|sos|>', 'm'), 4), (('p', 'er'), 4), (('<|sos|>', 'o'), 4), (('.', '<|eos|>'), 4), (('t', 'e'), 4)]
#
# Found Best Pair: ('<|sos|>', 'm'): best_freq: 4
#
# Merging ('<|sos|>', 'm') into <|sos|>m
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'p', 'er', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'p', 'er', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'p', 'er', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'p', 'er', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 10/15
#
# Top 5 Pair Frequencies: [(('p', 'er'), 4), (('<|sos|>', 'o'), 4), (('.', '<|eos|>'), 4), (('t', 'e'), 4), (('<|sos|>', 'w'), 4)]
#
# Found Best Pair: ('p', 'er'): best_freq: 4
#
# Merging ('p', 'er') into per
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 11/15
#
# Top 5 Pair Frequencies: [(('<|sos|>', 'o'), 4), (('.', '<|eos|>'), 4), (('t', 'e'), 4), (('<|sos|>', 'w'), 4), (('<|sos|>c', 'o'), 4)]
#
# Found Best Pair: ('<|sos|>', 'o'): best_freq: 4
#
# Merging ('<|sos|>', 'o') into <|sos|>o
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.', '<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.', '<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.', '<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.', '<|eos|>'): 1}
# ******************************
#
# Iteration 12/15
#
# Top 5 Pair Frequencies: [(('.', '<|eos|>'), 4), (('t', 'e'), 4), (('<|sos|>', 'w'), 4), (('<|sos|>c', 'o'), 4), (('d', 'e'), 3)]
#
# Found Best Pair: ('.', '<|eos|>'): best_freq: 4
#
# Merging ('.', '<|eos|>') into .<|eos|>
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 't', 'e', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 't', 'e', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 't', 'e', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.<|eos|>'): 1}
# ******************************
#
# Iteration 13/15
#
# Top 5 Pair Frequencies: [(('t', 'e'), 4), (('<|sos|>', 'w'), 4), (('<|sos|>c', 'o'), 4), (('d', 'e'), 3), (('f', 'or'), 3)]
#
# Found Best Pair: ('t', 'e'): best_freq: 4
#
# Merging ('t', 'e') into te
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 'te', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>', 'w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 'te', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'd', 'th', '.<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>', 'w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 'te', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 'te', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>', 'w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.<|eos|>'): 1}
# ******************************
#
# Iteration 14/15
#
# Top 5 Pair Frequencies: [(('<|sos|>', 'w'), 4), (('<|sos|>c', 'o'), 4), (('d', 'e'), 3), (('f', 'or'), 3), (('or', 'm'), 3)]
#
# Found Best Pair: ('<|sos|>', 'w'): best_freq: 4
#
# Merging ('<|sos|>', 'w') into <|sos|>w
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 'te', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>c', 'o', 'n', 't', 'r', 'i', 'b', 'u', 'te', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>c', 'o', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'd', 'th', '.<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>c', 'o', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 'te', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>c', 'o', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 'te', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.<|eos|>'): 1}
# ******************************
#
# Iteration 15/15
#
# Top 5 Pair Frequencies: [(('<|sos|>c', 'o'), 4), (('d', 'e'), 3), (('f', 'or'), 3), (('or', 'm'), 3), (('a', 'n'), 3)]
#
# Found Best Pair: ('<|sos|>c', 'o'): best_freq: 4
#
# Merging ('<|sos|>c', 'o') into <|sos|>co
#
#  Splits after merge: {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 'te', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>co', 'n', 't', 'r', 'i', 'b', 'u', 'te', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>co', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'd', 'th', '.<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>co', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 'te', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>co', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 'te', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.<|eos|>'): 1}
# ******************************

# %%
print("\n---BPE Merges Complete---")
print(f"Final Vocab Size: {len(vocabulary)}")
print(f"Learned Merges: (Pair --> New Token)")

for pair, token in merges.items():
  print(f"{pair} --> {token}")

print("*"*37)
print(f"\n{current_splits}")
# Out:
# ---BPE Merges Complete---
# Final Vocab Size: 49
# Learned Merges: (Pair --> New Token)
# ('e', 'r') --> er
# ('e', '<|eos|>') --> e<|eos|>
# ('o', 'r') --> or
# ('i', 'n') --> in
# ('n', '<|eos|>') --> n<|eos|>
# ('s', '<|eos|>') --> s<|eos|>
# ('<|sos|>', 'c') --> <|sos|>c
# ('t', 'h') --> th
# ('<|sos|>', 'm') --> <|sos|>m
# ('p', 'er') --> per
# ('<|sos|>', 'o') --> <|sos|>o
# ('.', '<|eos|>') --> .<|eos|>
# ('t', 'e') --> te
# ('<|sos|>', 'w') --> <|sos|>w
# ('<|sos|>c', 'o') --> <|sos|>co
# *************************************
#
# {('<|sos|>', 'T', 'h', 'e<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', '’', 's<|eos|>'): 1, ('<|sos|>', 'per', 'f', 'or', 'm', 'a', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'i', 'm', 'p', 'r', 'o', 'v', 'e', 'd', '<|eos|>'): 1, ('<|sos|>', 's', 'l', 'i', 'g', 'h', 't', 'l', 'y', '<|eos|>'): 1, ('<|sos|>', 'a', 'f', 't', 'er', '<|eos|>'): 1, ('<|sos|>', 'f', 'in', 'e', '-', 't', 'u', 'n', 'in', 'g', '<|eos|>'): 1, ('<|sos|>o', 'n<|eos|>'): 1, ('<|sos|>', 'd', 'o', 'm', 'a', 'in', '-', 's', 'p', 'e', 'c', 'i', 'f', 'i', 'c', '<|eos|>'): 1, ('<|sos|>', 'd', 'a', 't', 'a', '.<|eos|>'): 1, ('<|sos|>', 'A', '<|eos|>'): 1, ('<|sos|>', 'l', 'i', 'g', 'h', 't', 'w', 'e', 'i', 'g', 'h', 't', '<|eos|>'): 1, ('<|sos|>', 't', 'r', 'a', 'n', 's', 'f', 'or', 'm', 'er', '<|eos|>'): 1, ('<|sos|>c', 'a', 'n<|eos|>'): 1, ('<|sos|>o', 'f', 'te', 'n<|eos|>'): 1, ('<|sos|>o', 'u', 't', 'per', 'f', 'or', 'm', '<|eos|>'): 1, ('<|sos|>', 'l', 'a', 'r', 'g', 'er', '<|eos|>'): 1, ('<|sos|>m', 'o', 'd', 'e', 'l', 's<|eos|>'): 1, ('<|sos|>w', 'h', 'e', 'n<|eos|>'): 1, ('<|sos|>', 'p', 'r', 'o', 'per', 'l', 'y', '<|eos|>'): 1, ('<|sos|>o', 'p', 't', 'i', 'm', 'i', 'z', 'e', 'd', '.<|eos|>'): 1, ('<|sos|>', 'E', 'x', 'per', 'i', 'm', 'e', 'n', 't', 'a', 'l', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 's', 'u', 'l', 't', 's<|eos|>'): 1, ('<|sos|>', 's', 'h', 'o', 'w', '<|eos|>'): 1, ('<|sos|>', 'th', 'a', 't', '<|eos|>'): 1, ('<|sos|>', 's', 'c', 'a', 'l', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'd', 'e', 'p', 'th', '<|eos|>'): 1, ('<|sos|>co', 'n', 't', 'r', 'i', 'b', 'u', 'te', 's<|eos|>'): 1, ('<|sos|>m', 'or', 'e<|eos|>'): 1, ('<|sos|>', 't', 'o', '<|eos|>'): 1, ('<|sos|>co', 'h', 'er', 'e', 'n', 'c', 'e<|eos|>'): 1, ('<|sos|>', 'th', 'a', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'd', 'th', '.<|eos|>'): 1, ('<|sos|>', 'F', 'u', 't', 'u', 'r', 'e<|eos|>'): 1, ('<|sos|>w', 'or', 'k', '<|eos|>'): 1, ('<|sos|>co', 'u', 'l', 'd', '<|eos|>'): 1, ('<|sos|>', 'e', 'x', 'p', 'l', 'or', 'e<|eos|>'): 1, ('<|sos|>', 'h', 'y', 'b', 'r', 'i', 'd', '<|eos|>'): 1, ('<|sos|>', 'a', 'r', 'c', 'h', 'i', 'te', 'c', 't', 'u', 'r', 'e', 's<|eos|>'): 1, ('<|sos|>co', 'm', 'b', 'in', 'in', 'g', '<|eos|>'): 1, ('<|sos|>', 'a', 't', 'te', 'n', 't', 'i', 'o', 'n<|eos|>'): 1, ('<|sos|>w', 'i', 'th', '<|eos|>'): 1, ('<|sos|>', 'r', 'e', 't', 'r', 'i', 'e', 'v', 'a', 'l', '<|eos|>'): 1, ('<|sos|>m', 'e', 'c', 'h', 'a', 'n', 'i', 's', 'm', 's', '.<|eos|>'): 1}
